# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **Data Source**
# # `https://data.mendeley.com/datasets/4drtyfjtfy/1`
#
# Ajayi, Gbeminiyi (2018), “Multi-class Weather Dataset for Image Classification”, Mendeley Data, V1, doi: 10.17632/4drtyfjtfy.1

# %%
! pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 899.0/899.0 kB 21.5 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolo11n-cls.pt')

DATA_DIR = '/content/drive/MyDrive/Colab Notebooks/Multi-class Weather Dataset for Image Classification/weather image dataset'
results = model.train(data= DATA_DIR ,epochs= 10, imgsz = 64)
# Out:
# Ultralytics 8.3.50 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# !scp -r /content/runs '/content/drive/MyDrive/Colab Notebooks/Multi-class Weather Dataset for Image Classification/'
